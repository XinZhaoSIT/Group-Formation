# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('skill_data_label.csv')
df
# Out:
#         Teamwork  Empathy_skills  Self-control  Ability_to_compromise  \
# 0             87              80            97                     75
# 1             85              73            83                     79
# 2             89              63            87                     87
# 3             80              74            77                     89
# 4             66              92            70                     78
# ...          ...             ...           ...                    ...
# 999995        76              82            82                     91
# 999996        81              85            85                     78
# 999997        85              79            65                     77
# 999998        68              85            84                     70
# 999999        91              60            67                     69
#
#         Ability_to_teach  Respect_for_others  Openness_to_Criticism  \
# ...

# %%
table = pd.pivot_table(df, values=['Teamwork','Empathy_skills','Self-control','Ability_to_compromise',\
                    'Ability_to_teach','Respect_for_others','Openness_to_Criticism','Sensitivity_and_Tact',\
                             'Gaining_trust','Comfort_with_Differences','Listening_Skills'],\
                    index=['label'],
                    aggfunc=[np.mean])
table
# Out:
#                        mean                                            \
#       Ability_to_compromise Ability_to_teach Comfort_with_Differences
# label
# 0                 75.747302        79.819552                83.075668
# 1                 78.856119        77.846010                77.474547
# 2                 81.028625        78.014854                76.687248
# 3                 84.291545        84.224302                82.776674
#
#                                                                            \
#       Empathy_skills Gaining_trust Listening_Skills Openness_to_Criticism
# label
# 0          77.335724     83.023831        83.304130             79.460293
# 1          80.817845     75.637781        76.885786             77.888883
# 2          76.670768     79.768509        78.074821             79.017423
# 3          85.016492     81.677487        81.752570             83.557509
#
#
#       Respect_for_others Self-control Sensitivity_and_Tact   Teamwork
# label
# ...

# %%
table.T.plot(figsize=(10,6), \
             xlabel='Interpersonal skills',\
             ylabel='Average score')
plt.xticks(np.arange(11), ['Compromise','Teach',\
                           'Comfort_Diff','Empathy',\
                           'Gaining_trust','Listening',\
                           'Openness_to_Criticism','Respect',\
                           'Self-control','Tact','Teamwork'], rotation=45)
plt.title('Interpersonal Skills clusters')
plt.legend(loc='upper left')
plt.show()

# %%
table2 = pd.pivot_table(df,values='Teamwork',\
                    index=['label'],
                     aggfunc='count')
table2.rename(columns={'Teamwork':'count'}, inplace=True)
table2
# Out:
#         count
# label
# 0      246658
# 1      254426
# 2      244852
# 3      254064

# %%
table2.plot.bar()
plt.title('cluster size')
plt.ylabel('count')
plt.xticks(rotation=0)
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, '0'), Text(1, 0, '1'), Text(2, 0, '2'), Text(3, 0, '3')])
